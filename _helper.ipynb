# %%
from src.datasets import XorDataset

# %%
data = XorDataset.from_random(size=50000)

# %%
# Out:
# dtype('float64')

# %%
import matplotlib.pyplot as plt
plt.scatter(data.X[:, 0], data.X[:, 1], c=data.y, cmap='binary', edgecolors='grey')

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# create a 2D XOR dataset
@np.vectorize
def fn(x1, x2):
    return 1 if x1 * x2 > 0 else 0

def create_xor_dataset(size=1000):
    x1 = np.random.uniform(-1, 1, size)
    x2 = np.random.uniform(-1, 1, size)
    y = fn(x1, x2)
    return np.stack([x1, x2], axis=1), y

# %%
X, y = create_xor_dataset(10000)

# %%
x1 = np.random.uniform(-1, 1, 3)
x2 = np.random.uniform(-1, 1, 3)
fn(x1, x2)
# Out:
# array([1, 0, 0])

# %%
print(*zip(x1, x2))
# Out:
# (0.8309009466235309, 0.39487639258194185) (-0.02335068869410395, 0.9320874370048149) (0.5844231109205027, -0.883666882341209)

# %%
x1
# Out:
# array([ 0.72191007, -0.41667341,  0.4575452 ])

# %%
x2
# Out:
# array([ 0.66864283, -0.46486153,  0.5888422 ])
